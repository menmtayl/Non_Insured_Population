# %% [markdown]
# DATA: Medicare data displaying the 2016 use of Medicare and Medicare savings across the US.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pyplot
import seaborn as sns

df = pd.read_csv('Medicare ACA state data 12_2016.csv')
print(df.info)
# Out:
# <bound method DataFrame.info of     index                 State  Medicare Enrollment (Sept. 2016)  \
# 0       0              Alabama                           989855.0
# 1       1               Alaska                            88966.0
# 2       2              Arizona                          1175624.0
# 3       3             Arkansas                           606146.0
# 4       4            California                         5829777.0
# 5       5              Colorado                          820234.0
# 6       6           Connecticut                          644136.0
# 7       7             Delaware                           186835.0
# 8       8  District of Columbia                           90492.0
# 9       9              Florida                          4149593.0
# 10     10              Georgia                          1574058.0
# 11     11                Hawaii                          252514.0
# 12     12                 Idaho                          294284.0
# ...

# %%
import pandas as pd

df = pd.read_csv('Medicare ACA state data 12_2016.csv')
df.info()
print
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 13 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   index                                                                            54 non-null     int64
#  1   State                                                                            51 non-null     object
#  2   Medicare Enrollment (Sept. 2016)                                                 51 non-null     float64
#  3   Medicare Beneficiaries benefitting from donut hole savings (2015)                51 non-null     float64
#  4   Total Medicare beneficiary savings from donut hole (2015)                        51 non-null     float64
#  5   Average per Medicare Beneficiary Donut Hole Savings (2015)                       51 non-null     float64
# ...

# %%
import pandas as pd

df = pd.read_csv('Medicare ACA state data 12_2016.csv')
df.describe()
# Out:
#            index  Medicare Enrollment (Sept. 2016)  \
# count  54.000000                      5.100000e+01
# mean   26.500000                      1.095961e+06
# std    15.732133                      1.147094e+06
# min     0.000000                      8.896600e+04
# 25%    13.250000                      3.189780e+05
# 50%    26.500000                      8.172720e+05
# 75%    39.750000                      1.259598e+06
# max    53.000000                      5.829777e+06
#
#        Medicare Beneficiaries benefitting from donut hole savings (2015)  \
# count                                          51.000000
# mean                                        98964.529412
# std                                        103440.955454
# min                                          3094.000000
# 25%                                         23992.500000
# 50%                                         66843.000000
# 75%                                        114565.500000
# ...

# %%
df.head()
column_list = list(df.columns)
column_list
# Out:
# ['index',
#  'State',
#  'Medicare Enrollment (Sept. 2016)',
#  'Medicare Beneficiaries benefitting from donut hole savings (2015)',
#  'Total Medicare beneficiary savings from donut hole (2015)',
#  'Average per Medicare Beneficiary Donut Hole Savings (2015)',
#  'Part B Beneficiaries Using Free Preventive Services (2015)',
#  'Share of Part B Beneficiaries Using Free Preventive Services (2015)',
#  '% Change in Hospital Readmission Rates Among Medicare Beneficiaries (2010-2015)',
#  'Avoided Readmissions (2015)',
#  'Number of Accountable Care Organizations (2016)',
#  'Unnamed: 10',
#  'Unnamed: 11']

# %%
df = df.drop(['Unnamed: 10', 'Unnamed: 11'], axis=1)
print(df)
# Out:
#     index                 State  Medicare Enrollment (Sept. 2016)  \
# 0       0              Alabama                           989855.0
# 1       1               Alaska                            88966.0
# 2       2              Arizona                          1175624.0
# 3       3             Arkansas                           606146.0
# 4       4            California                         5829777.0
# 5       5              Colorado                          820234.0
# 6       6           Connecticut                          644136.0
# 7       7             Delaware                           186835.0
# 8       8  District of Columbia                           90492.0
# 9       9              Florida                          4149593.0
# 10     10              Georgia                          1574058.0
# 11     11                Hawaii                          252514.0
# 12     12                 Idaho                          294284.0
# ...

# %%
print(df.isna().sum())
# Out:
# index                                                                              0
# State                                                                              3
# Medicare Enrollment (Sept. 2016)                                                   3
# Medicare Beneficiaries benefitting from donut hole savings (2015)                  3
# Total Medicare beneficiary savings from donut hole (2015)                          3
# Average per Medicare Beneficiary Donut Hole Savings (2015)                         3
# Part B Beneficiaries Using Free Preventive Services (2015)                         3
# Share of Part B Beneficiaries Using Free Preventive Services (2015)                3
# % Change in Hospital Readmission Rates Among Medicare Beneficiaries (2010-2015)    3
# Avoided Readmissions (2015)                                                        3
# Number of Accountable Care Organizations (2016)                                    3
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#     index                 State  Medicare Enrollment (Sept. 2016)  \
# 0       0              Alabama                           989855.0
# 1       1               Alaska                            88966.0
# 2       2              Arizona                          1175624.0
# 3       3             Arkansas                           606146.0
# 4       4            California                         5829777.0
# 5       5              Colorado                          820234.0
# 6       6           Connecticut                          644136.0
# 7       7             Delaware                           186835.0
# 8       8  District of Columbia                           90492.0
# 9       9              Florida                          4149593.0
# 10     10              Georgia                          1574058.0
# 11     11                Hawaii                          252514.0
# 12     12                 Idaho                          294284.0
# ...

# %% [markdown]
# DATASET #2

# %%
import pandas as pd

df = pd.read_csv('the-number-of-estimated-eligible-uninsured-people-for-outreach-targeting.csv')
df.head()
print(df)
# Out:
#       StateName  StateFIPS  PumaState  PUMA  \
# 0       Alabama          1     100100   100
# 1       Alabama          1     100200   200
# 2       Alabama          1     100300   300
# 3       Alabama          1     100400   400
# 4       Alabama          1     100500   500
# ...         ...        ...        ...   ...
# 2064  Wisconsin         55    5502500  2500
# 2065    Wyoming         56    5600100   100
# 2066    Wyoming         56    5600200   200
# 2067    Wyoming         56    5600300   300
# 2068    Wyoming         56    5600400   400
#
#                                    Counties Within PUMA  uninsured_total  \
# 0                     Lauderdale County, Colbert County            18517
# 1                                 Madison County (part)            28109
# 2                                 Madison County (part)            26568
# 3                         DeKalb County, Jackson County            21245
# ...

# %%
import pandas as pd

df = pd.read_csv('the-number-of-estimated-eligible-uninsured-people-for-outreach-targeting.csv')
df.describe()
print(df)
# Out:
#       StateName  StateFIPS  PumaState  PUMA  \
# 0       Alabama          1     100100   100
# 1       Alabama          1     100200   200
# 2       Alabama          1     100300   300
# 3       Alabama          1     100400   400
# 4       Alabama          1     100500   500
# ...         ...        ...        ...   ...
# 2064  Wisconsin         55    5502500  2500
# 2065    Wyoming         56    5600100   100
# 2066    Wyoming         56    5600200   200
# 2067    Wyoming         56    5600300   300
# 2068    Wyoming         56    5600400   400
#
#                                    Counties Within PUMA  uninsured_total  \
# 0                     Lauderdale County, Colbert County            18517
# 1                                 Madison County (part)            28109
# 2                                 Madison County (part)            26568
# 3                         DeKalb County, Jackson County            21245
# ...

# %%
import pandas as pd
df = pd.read_csv('the-number-of-estimated-eligible-uninsured-people-for-outreach-targeting.csv')
df.info()
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2069 entries, 0 to 2068
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   StateName                      2069 non-null   object
#  1   StateFIPS                      2069 non-null   int64
#  2   PumaState                      2069 non-null   int64
#  3   PUMA                           2069 non-null   int64
#  4   Counties Within PUMA           2069 non-null   object
#  5   uninsured_total                2069 non-null   int64
#  6   uninsured_percent              2069 non-null   float64
#  7   Foodstamp                      2058 non-null   float64
#  8   Age0_18                        2061 non-null   float64
#  9   Age19_25                       2069 non-null   int64
#  10  Age26_34                       2068 non-null   float64
#  11  Age35_54                       2069 non-null   object
# ...

# %%
df.head()
column_list = list(df.columns)
column_list
# Out:
# ['StateName',
#  'StateFIPS',
#  'PumaState',
#  'PUMA',
#  'Counties Within PUMA',
#  'uninsured_total',
#  'uninsured_percent',
#  'Foodstamp',
#  'Age0_18',
#  'Age19_25',
#  'Age26_34',
#  'Age35_54',
#  'Age55_64',
#  '138PctFPL_or_Less',
#  '139to400PctFPL',
#  'Above400PctFPL',
#  'Male',
#  'Female',
#  'Married',
#  'ChildinFamily',
#  'Latino',
#  'WhiteNonLatino',
#  'BlackNonLatino',
#  'AsianNonLatino',
#  'HawaiiPacIslander',
#  'AmericanIndian_AlaskaNative',
#  'Multiracial_or_Other',
#  'Disabled',
#  'FullTime_Worker_in_Family',
#  'Job_Agriculture',
#  'Job_Mining',
#  'Job_ManufacturingConstruction',
#  'Job_Trade',
#  'Job_InfoFinance',
#  'Job_EducHealth',
#  'Job_Entertainment',
#  'Job_Service',
#  'Job_MilitaryPublic',
#  'LessThanHS',
#  'HSDiploma',
#  'CollegeGrad',
#  'NoEnglishAdults_in_House',
#  'EnglishSpeaking',
#  'Spanish',
#  'Chinese',
#  'Korean',
#  'Vietnamese',
#  'Tagalog',
#  'Russian',
#  'OtherLang',
#  'SpeaksMostCommonOthLang',
# ...

# %%
print(df.shape)
# Out:
# (2069, 52)

# %%
print(df.columns)
# Out:
# Index(['StateName', 'StateFIPS', 'PumaState', 'PUMA', 'Counties Within PUMA',
#        'uninsured_total', 'uninsured_percent', 'Foodstamp', 'Age0_18',
#        'Age19_25', 'Age26_34', 'Age35_54', 'Age55_64', '138PctFPL_or_Less',
#        '139to400PctFPL', 'Above400PctFPL', 'Male', 'Female', 'Married',
#        'ChildinFamily', 'Latino', 'WhiteNonLatino', 'BlackNonLatino',
#        'AsianNonLatino', 'HawaiiPacIslander', 'AmericanIndian_AlaskaNative',
#        'Multiracial_or_Other', 'Disabled', 'FullTime_Worker_in_Family',
#        'Job_Agriculture', 'Job_Mining', 'Job_ManufacturingConstruction',
#        'Job_Trade', 'Job_InfoFinance', 'Job_EducHealth', 'Job_Entertainment',
#        'Job_Service', 'Job_MilitaryPublic', 'LessThanHS', 'HSDiploma',
#        'CollegeGrad', 'NoEnglishAdults_in_House', 'EnglishSpeaking', 'Spanish',
#        'Chinese', 'Korean', 'Vietnamese', 'Tagalog', 'Russian', 'OtherLang',
#        'SpeaksMostCommonOthLang', 'OtherLanguage'],
#       dtype='object')

# %%
df = df.drop(['138PctFPL_or_Less', '139to400PctFPL', 'Above400PctFPL', 'HawaiiPacIslander', 'AmericanIndian_AlaskaNative',
       'Job_Agriculture', 'Job_Mining', 'Job_ManufacturingConstruction', 'Job_Trade', 'Job_InfoFinance', 'Job_EducHealth', 'Job_Entertainment', 'Job_Service', 'Job_MilitaryPublic',
       'Chinese', 'Korean', 'Vietnamese', 'Tagalog', 'Russian', 'OtherLang', 'SpeaksMostCommonOthLang','OtherLanguage'], axis=1)
print(df)
# Out:
#       StateName  StateFIPS  PumaState  PUMA  \
# 0       Alabama          1     100100   100
# 1       Alabama          1     100200   200
# 2       Alabama          1     100300   300
# 3       Alabama          1     100400   400
# 4       Alabama          1     100500   500
# ...         ...        ...        ...   ...
# 2064  Wisconsin         55    5502500  2500
# 2065    Wyoming         56    5600100   100
# 2066    Wyoming         56    5600200   200
# 2067    Wyoming         56    5600300   300
# 2068    Wyoming         56    5600400   400
#
#                                    Counties Within PUMA  uninsured_total  \
# 0                     Lauderdale County, Colbert County            18517
# 1                                 Madison County (part)            28109
# 2                                 Madison County (part)            26568
# 3                         DeKalb County, Jackson County            21245
# ...

# %%
print(df.isna().sum())
# Out:
# StateName                           0
# StateFIPS                           0
# PumaState                           0
# PUMA                                0
# Counties Within PUMA                0
# uninsured_total                     0
# uninsured_percent                   0
# Foodstamp                          11
# Age0_18                             8
# Age19_25                            0
# Age26_34                            1
# Age35_54                            0
# Age55_64                            0
# 138PctFPL_or_Less                   0
# 139to400PctFPL                      0
# Above400PctFPL                      0
# Male                                0
# Female                              0
# Married                             0
# ChildinFamily                       0
# Latino                              0
# WhiteNonLatino                      0
# BlackNonLatino                      0
# AsianNonLatino                      0
# HawaiiPacIslander                   0
# ...

# %%
df = df.dropna(subset = ["Foodstamp", "Age0_18", "Age26_34", "Spanish", "NoEnglishAdults_in_House"])

# %%
df.isna().sum()
# Out:
# StateName                    0
# StateFIPS                    0
# PumaState                    0
# PUMA                         0
# Counties Within PUMA         0
# uninsured_total              0
# uninsured_percent            0
# Foodstamp                    0
# Age0_18                      0
# Age19_25                     0
# Age26_34                     0
# Age35_54                     0
# Age55_64                     0
# Male                         0
# Female                       0
# Married                      0
# ChildinFamily                0
# Latino                       0
# WhiteNonLatino               0
# BlackNonLatino               0
# AsianNonLatino               0
# Multiracial_or_Other         0
# Disabled                     0
# FullTime_Worker_in_Family    0
# LessThanHS                   0
# HSDiploma                    0
# CollegeGrad                  0
# NoEnglishAdults_in_House     0
# EnglishSpeaking              0
# Spanish                      0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()
print(df)
# Out:
#       StateName  StateFIPS  PumaState  PUMA  \
# 0       Alabama          1     100100   100
# 1       Alabama          1     100200   200
# 2       Alabama          1     100300   300
# 3       Alabama          1     100400   400
# 4       Alabama          1     100500   500
# ...         ...        ...        ...   ...
# 2064  Wisconsin         55    5502500  2500
# 2065    Wyoming         56    5600100   100
# 2066    Wyoming         56    5600200   200
# 2067    Wyoming         56    5600300   300
# 2068    Wyoming         56    5600400   400
#
#                                    Counties Within PUMA  uninsured_total  \
# 0                     Lauderdale County, Colbert County            18517
# 1                                 Madison County (part)            28109
# 2                                 Madison County (part)            26568
# 3                         DeKalb County, Jackson County            21245
# ...

# %%
df.info()
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1834 entries, 0 to 2068
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StateName                  1834 non-null   object
#  1   StateFIPS                  1834 non-null   int64
#  2   PumaState                  1834 non-null   int64
#  3   PUMA                       1834 non-null   int64
#  4   Counties Within PUMA       1834 non-null   object
#  5   uninsured_total            1834 non-null   int64
#  6   uninsured_percent          1834 non-null   float64
#  7   Foodstamp                  1834 non-null   float64
#  8   Age0_18                    1834 non-null   float64
#  9   Age19_25                   1834 non-null   int64
#  10  Age26_34                   1834 non-null   float64
#  11  Age35_54                   1834 non-null   object
#  12  Age55_64                   1834 non-null   object
# ...

# %%
df.describe()
# Out:
#          StateFIPS     PumaState          PUMA  uninsured_total  \
# count  1834.000000  1.834000e+03   1834.000000      1834.000000
# mean     26.881679  2.690515e+06   2346.959106     20913.197928
# std      16.016790  1.601496e+06   2507.490858     10251.781532
# min       1.000000  1.001000e+05    100.000000      1305.000000
# 25%      12.000000  1.202801e+06    900.000000     13392.000000
# 50%      26.000000  2.603703e+06   1952.000000     19245.000000
# 75%      41.000000  4.100275e+06   3501.000000     26539.250000
# max      56.000000  5.600400e+06  77777.000000     86343.000000
#
#        uninsured_percent     Foodstamp       Age0_18      Age19_25  \
# count        1834.000000   1834.000000   1834.000000   1834.000000
# mean           16.261559   5021.521265   2931.963468   3910.552345
# std             6.535281   3640.675056   2405.003087   2193.523575
# min             1.500000     47.000000     69.000000    136.000000
# ...

# %%
df["StateFIPS"] = df["StateFIPS"].astype(object)
df.dtypes

df["PumaState"] = df["PumaState"].astype(object)
df.dtypes

df["PUMA"] = df["PUMA"].astype(object)
df.dtypes

df["StateName"] = df["StateName"].astype(object)

df["Counties Within PUMA"] = df["Counties Within PUMA"].astype(object)

# %%
df
# Out:
#       StateName StateFIPS PumaState  PUMA  \
# 0       Alabama         1    100100   100
# 1       Alabama         1    100200   200
# 2       Alabama         1    100300   300
# 3       Alabama         1    100400   400
# 4       Alabama         1    100500   500
# ...         ...       ...       ...   ...
# 2064  Wisconsin        55   5502500  2500
# 2065    Wyoming        56   5600100   100
# 2066    Wyoming        56   5600200   200
# 2067    Wyoming        56   5600300   300
# 2068    Wyoming        56   5600400   400
#
#                                    Counties Within PUMA  uninsured_total  \
# 0                     Lauderdale County, Colbert County            18517
# 1                                 Madison County (part)            28109
# 2                                 Madison County (part)            26568
# 3                         DeKalb County, Jackson County            21245
# 4       Marshall County, Cullman County, Winston County            25654
# ...

# %%
df = df.replace(r"[\,\**\-\.0\'  ']", '', regex=True)
df
# Out:
# C:\Users\menmt\AppData\Local\Temp\ipykernel_2548\4066847586.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r"[\,\**\-\.0\'  ']", '', regex=True)
#       StateName  StateFIPS  PumaState  PUMA  \
# 0       Alabama          1     100100   100
# 1       Alabama          1     100200   200
# 2       Alabama          1     100300   300
# 3       Alabama          1     100400   400
# 4       Alabama          1     100500   500
# ...         ...        ...        ...   ...
# 2064  Wisconsin         55    5502500  2500
# 2065    Wyoming         56    5600100   100
# 2066    Wyoming         56    5600200   200
# 2067    Wyoming         56    5600300   300
# 2068    Wyoming         56    5600400   400
#
# ...

# %%
df["Male"] = df["Male"].astype(int)
df.dtypes

df["Age0_18"] = df["Age0_18"].astype(int)
df.dtypes

df["Foodstamp"] = df["Foodstamp"].astype(int)
df.dtypes

df["Age26_34"] = df["Age26_34"].astype(int)

df["Age35_54"] = df["Age35_54"].astype(int)

df["Age55_64"] = df["Age55_64"].astype(int)
df.dtypes

df["Female"] = df["Female"].astype(int)
df.dtypes

df["Married"] = df["Married"].astype(int)
df.dtypes

df["ChildinFamily"] = df["ChildinFamily"].astype(int)

# %%
df.dtypes
# Out:
# StateName                     object
# StateFIPS                     object
# PumaState                     object
# PUMA                          object
# Counties Within PUMA          object
# uninsured_total                int64
# uninsured_percent            float64
# Foodstamp                      int64
# Age0_18                        int64
# Age19_25                       int64
# Age26_34                       int64
# Age35_54                       int64
# Age55_64                       int64
# Male                           int64
# Female                         int64
# Married                        int64
# ChildinFamily                  int64
# Latino                        object
# WhiteNonLatino                object
# BlackNonLatino                object
# AsianNonLatino                object
# Multiracial_or_Other          object
# Disabled                      object
# FullTime_Worker_in_Family     object
# LessThanHS                    object
# ...

# %%
df['StateFIPS'] = df['StateFIPS'].astype(object)
df.dtypes

df["PumaState"] = df["PumaState"].astype(object)
df.dtypes

df["PUMA"] = df["PUMA"].astype(object)
df.dtypes

df["StateName"] = df["StateName"].astype(object)

df["Counties Within PUMA"] = df["Counties Within PUMA"].astype(object)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\menmt\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'StateFIPS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[432], line 1
# ----> 1 df['StateFIPS'] = df['StateFIPS'].astype(object)
#       2 df.dtypes
#       4 df["PumaState"] = df["PumaState"].astype(object)
#
# ...

# %%
df = df.astype({'Age35_54':  int,'Age55_64': int, 'Male': int, 'Female': int, 'Married': int, 'ChildinFamily': int, 'WhiteNonLatino': int, 'BlackNonLatino': int, 'AsianNonLatino': int, 'Multiracial_or_Other': int, 'Disabled': int, 'FullTime_Worker_in_Family': int, 'LessThanHS': int, 'HSDiploma': int, 'CollegeGrad': int, 'NoEnglishAdults_in_House': int, 'EnglishSpeaking': int, 'Spanish': int}) 
print("\nConverted:\n")
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2548\1554525033.py in ?()
# ----> 1 df = df.astype({'Age35_54':  int,'Age55_64': int, 'Male': int, 'Female': int, 'Married': int, 'ChildinFamily': int, 'WhiteNonLatino': int, 'BlackNonLatino': int, 'AsianNonLatino': int, 'Multiracial_or_Other': int, 'Disabled': int, 'FullTime_Worker_in_Family': int, 'LessThanHS': int, 'HSDiploma': int, 'CollegeGrad': int, 'NoEnglishAdults_in_House': int, 'EnglishSpeaking': int, 'Spanish': int})
#       2 print("\nConverted:\n")
#       3 print(df.dtypes)
#
# c:\Users\menmt\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6586
#    6587         if is_dict_like(dtype):
#    6588             if self.ndim == 1:  # i.e. Series
#    6589                 if len(dtype) > 1 or self.name not in dtype:
# ...

# %%
df.sample
# Out:
# <bound method NDFrame.sample of       StateName  StateFIPS  PumaState  PUMA  \
# 0       Alabama          1     100100   100
# 1       Alabama          1     100200   200
# 2       Alabama          1     100300   300
# 3       Alabama          1     100400   400
# 4       Alabama          1     100500   500
# ...         ...        ...        ...   ...
# 2064  Wisconsin         55    5502500  2500
# 2065    Wyoming         56    5600100   100
# 2066    Wyoming         56    5600200   200
# 2067    Wyoming         56    5600300   300
# 2068    Wyoming         56    5600400   400
#
#                                    Counties Within PUMA  uninsured_total  \
# 0                         LauderdaleCountyColbertCounty            18517
# 1                                   MadisonCounty(part)            28109
# 2                                   MadisonCounty(part)            26568
# 3                             DeKalbCountyJacksonCounty            21245
# ...

# %%
 #, 'Age55_64': 'int', 'Male': int, 'Female': int, 'Married': int, 'ChildinFamily': int, 'Latino': int, 'WhiteNonLatino': int, 'BlackNonLatino': int, 'AsianNonLatino': int, 'Multiracial_or_Other': int, 'Disabled': int, 'FullTime_Worker_in_Family': int, 'LessThanHS': int, 'HSDiploma': int, 'CollegeGrad': int, 'NoEnglishAdults_in_House': int, 'EnglishSpeaking': int, 'Spanish': int, 'OtherLanguage': int})

# %%
df.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# SQL

# %% [markdown]
# VISUALIZATIONS
